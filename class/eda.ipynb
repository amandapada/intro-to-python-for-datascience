# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5

# %% [markdown]
# *Italics*

# %% [markdown]
# **Bold**

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# ...

# %%
df.columns
# Out:
# Index(['id', 'NumDots', 'SubdomainLevel', 'PathLevel', 'UrlLength', 'NumDash',
#        'NumDashInHostname', 'AtSymbol', 'TildeSymbol', 'NumUnderscore',
#        'NumPercent', 'NumQueryComponents', 'NumAmpersand', 'NumHash',
#        'NumNumericChars', 'NoHttps', 'RandomString', 'IpAddress',
#        'DomainInSubdomains', 'DomainInPaths', 'HttpsInHostname',
#        'HostnameLength', 'PathLength', 'QueryLength', 'DoubleSlashInPath',
#        'NumSensitiveWords', 'EmbeddedBrandName', 'PctExtHyperlinks',
#        'PctExtResourceUrls', 'ExtFavicon', 'InsecureForms',
#        'RelativeFormAction', 'ExtFormAction', 'AbnormalFormAction',
#        'PctNullSelfRedirectHyperlinks', 'FrequentDomainNameMismatch',
#        'FakeLinkInStatusBar', 'RightClickDisabled', 'PopUpWindow',
#        'SubmitInfoToEmail', 'IframeOrFrame', 'MissingTitle',
#        'ImagesOnlyInForm', 'SubdomainLevelRT', 'UrlLengthRT',
#        'PctExtResourceUrlsRT', 'AbnormalExtFormActionR', 'ExtMetaScriptLinkRT',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int64
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# ...

# %%
df.nunique()
# Out:
# id                                    10000
# NumDots                                  17
# SubdomainLevel                           13
# PathLevel                                18
# UrlLength                               226
# NumDash                                  25
# NumDashInHostname                        10
# AtSymbol                                  2
# TildeSymbol                               2
# NumUnderscore                            16
# NumPercent                               14
# NumQueryComponents                       19
# NumAmpersand                             16
# NumHash                                   2
# NumNumericChars                          82
# NoHttps                                   2
# RandomString                              2
# IpAddress                                 2
# DomainInSubdomains                        2
# DomainInPaths                             2
# HttpsInHostname                           1
# ...

# %%
df["NumSensitiveWords"].unique()
# Out:
# array([0, 1, 2, 3])

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#    id  numdots  subdomainlevel  pathlevel  urllength  numdash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    numdashinhostname  atsymbol  tildesymbol  numunderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    iframeorframe  missingtitle  imagesonlyinform  subdomainlevelrt  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# ...

# %%
df_2= pd.read_csv('survey.csv')

# %%
df_2.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df_2.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df_2.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
df_2.describe(include='all')
# Out:
#                   Timestamp           Age Gender        Country state  \
# count                  1259  1.259000e+03   1259           1259   744
# unique                 1246           NaN     49             48    45
# top     2014-08-27 12:43:28           NaN   Male  United States    CA
# freq                      2           NaN    615            751   138
# mean                    NaN  7.942815e+07    NaN            NaN   NaN
# std                     NaN  2.818299e+09    NaN            NaN   NaN
# min                     NaN -1.726000e+03    NaN            NaN   NaN
# 25%                     NaN  2.700000e+01    NaN            NaN   NaN
# 50%                     NaN  3.100000e+01    NaN            NaN   NaN
# 75%                     NaN  3.600000e+01    NaN            NaN   NaN
# max                     NaN  1.000000e+11    NaN            NaN   NaN
#
#        self_employed family_history treatment work_interfere no_employees  \
# ...

# %%
df_2.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df_2.nunique()
# Out:
# Timestamp                    1246
# Age                            53
# Gender                         49
# Country                        48
# state                          45
# self_employed                   2
# family_history                  2
# treatment                       2
# work_interfere                  4
# no_employees                    6
# remote_work                     2
# tech_company                    2
# benefits                        3
# care_options                    3
# wellness_program                3
# seek_help                       3
# anonymity                       3
# leave                           5
# mental_health_consequence       3
# phys_health_consequence         3
# coworkers                       3
# supervisor                      3
# mental_health_interview         3
# phys_health_interview           3
# mental_vs_physical              3
# obs_consequence                 2
# comments                      160
# dtype: int64

# %%
df_2['Age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72])

# %% [markdown]
# Make the columns uniform
# There are outliers in the Age column

# %%
df_2['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand',
#        'Zimbabwe', 'Spain', 'Finland', 'Uruguay', 'Israel',
#        'Bosnia and Herzegovina', 'Hungary', 'Singapore', 'Japan',
#        'Nigeria', 'Croatia', 'Norway', 'Thailand', 'Denmark',
#        'Bahamas, The', 'Greece', 'Moldova', 'Georgia', 'China',
#        'Czech Republic', 'Philippines'], dtype=object)

# %% [markdown]
# #### **Data Cleaning**

# %%
df_2.columns = df_2.columns.str.lower()

# %%
df_2.head()
# Out:
#              timestamp  age  gender         country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df_2 = df_2[(df_2["age"] >= 18) & (df_2["age"] <= 60)]
df_2["age"].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24, 18, 28, 26, 22, 19, 25, 45, 21, 43, 56, 60, 54, 55, 48,
#        20, 57, 58, 47, 51, 49, 53])

# %%
df_2 = df_2.drop(["state", "comments", "timestamp"], axis=1)
df_2.columns
# Out:
# Index(['age', 'gender', 'country', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
#df_2 = df_2.drop("timestamp", axis=1)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1247 entries, 0 to 1258
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        1247 non-null   int64
#  1   gender                     1247 non-null   object
#  2   country                    1247 non-null   object
#  3   self_employed              1229 non-null   object
#  4   family_history             1247 non-null   object
#  5   treatment                  1247 non-null   object
#  6   work_interfere             986 non-null    object
#  7   no_employees               1247 non-null   object
#  8   remote_work                1247 non-null   object
#  9   tech_company               1247 non-null   object
#  10  benefits                   1247 non-null   object
#  11  care_options               1247 non-null   object
#  12  wellness_program           1247 non-null   object
# ...

# %%
df_2["no_employees"].unique()
# Out:
# array(['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000'],
#       dtype=object)

# %%
order = ['1-5', '6-25', '26-100', '100-500', '500-1000', 'More than 1000']

# %%
df_2['no_employees'] = pd.Categorical(df_2['no_employees'], categories=order, ordered=True)

# %%
df_2["no_employees"].unique()
# Out:
# ['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000']
# Categories (6, object): ['1-5' < '6-25' < '26-100' < '100-500' < '500-1000' < 'More than 1000']

# %%
df_2["no_employees"].value_counts()
# Out:
# no_employees
# 6-25              288
# 26-100            288
# More than 1000    280
# 100-500           175
# 1-5               157
# 500-1000           59
# Name: count, dtype: int64

# %% [markdown]
# ##### Series methods
#
# ```
# .unique()
# .value_counts()
# .mean()
# .isna()
# .dropna()
# .fillna()
# ```

# %% [markdown]
# ##### Dataframe methods
#
# ```
# df.head()
# df.tail()
# df.describe()
# df.info()
# df.drop()
# df.rename()
# df.merge()
# df.groupby()
# df.sort_values()
# df.sort_index()
# ```

# %% [markdown]
# ##### Work on both
# ```
# count()
# isna()
# fillna()
# astype()
# ```

# %%
df_2['gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'Enby', 'fluid',
#        'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'Malr', 'femail',
#        'Cis Man', 'ostensibly male, unsure what that really means'],
#       dtype=object)

# %%
df_2['gender'] = df_2['gender'].str.lower().str.strip()
df_2['gender'].nunique()
df_2['gender'].unique()
# Out:
# array(['female', 'm', 'male', 'male-ish', 'maile', 'trans-female',
#        'cis female', 'f', 'something kinda male?', 'cis male', 'woman',
#        'mal', 'male (cis)', 'queer/she/they', 'non-binary', 'femake',
#        'make', 'nah', 'enby', 'fluid', 'genderqueer', 'androgyne',
#        'agender', 'cis-female/femme', 'guy (-ish) ^_^',
#        'male leaning androgynous', 'man', 'trans woman', 'msle', 'neuter',
#        'female (trans)', 'queer', 'female (cis)', 'mail', 'malr',
#        'femail', 'cis man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
male = [m for m in df_2["gender"] if m.startswith('m') or m.startswith('guy')]
print(male)
# Out:
# ['m', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'm', 'male', 'm', 'male', 'm', 'male-ish', 'maile', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'male', 'male', 'm', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'm', 'male', 'male', 'm', 'male', 'male', 'm', 'male', 'm', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'mal
# ...

# %%
for m in df_2["gender"]:
    if m == 'cis male':
        male.append(m)

# %%
female = [f for f in df_2["gender"] if f.startswith('f') or f.startswith('w')]
print(female)
# Out:
# ['female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'f', 'f', 'female', 'female', 'female', 'female', 'female', 'f', 'f', 'woman', 'female', 'female', 'female', 'f', 'f', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'f', 'f', 'female', 'f', 'female', 'f', 'female', 'f', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'f', 'female', 'f', 'female', 'f', 'female', 'female', 'female', 'f', 'f', 'f', 'female', 'femake', 'f', 'f', 'f', 'female', 'female', 'woman', 'f', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'f', 'fluid', 'female', 'female', 'female', 'f', 'female', 'female', 'female', 'f', 'female', 'female', 'f', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'f', 'female', 'f', 'female', 'female', 'female', 'female', 'female', 'f', 'female', 'female', 'female', 
# ...

# %%
for f in df_2["gender"]:
    if f == 'cis female' or f == 'cis-female/femme':
        female.append(m)

# %%
# female.remove('fluid')
female.remove('female (trans)')

# %%
def clean_gender(gender):

    if gender in male:
        return 'male'
    elif gender in female:
        return  'female'
    else:
        return 'other'
    
df_2['gender'] = df_2['gender'].apply(clean_gender)

# %%
df_2['gender'].unique()
# Out:
# array(['female', 'male', 'other'], dtype=object)

# %%
df_2['country'] = df_2['country'].str.lower().str.strip().str.replace(" ", "_")

# %%
df_2["country"].unique()
# Out:
# array(['united_states', 'canada', 'united_kingdom', 'bulgaria', 'france',
#        'portugal', 'netherlands', 'switzerland', 'poland', 'australia',
#        'germany', 'russia', 'mexico', 'brazil', 'slovenia', 'costa_rica',
#        'austria', 'ireland', 'india', 'south_africa', 'italy', 'sweden',
#        'colombia', 'latvia', 'romania', 'belgium', 'new_zealand', 'spain',
#        'finland', 'uruguay', 'israel', 'bosnia_and_herzegovina',
#        'hungary', 'singapore', 'japan', 'nigeria', 'croatia', 'norway',
#        'thailand', 'denmark', 'greece', 'moldova', 'georgia', 'china',
#        'czech_republic', 'philippines'], dtype=object)

# %%
df_2 = df_2[df_2["country"] == 'united_states']

# %%
df_2.head()
# Out:
#    age  gender        country self_employed family_history treatment  \
# 0   37  female  united_states           NaN             No       Yes
# 1   44    male  united_states           NaN             No        No
# 4   31    male  united_states           NaN             No        No
# 5   33    male  united_states           NaN            Yes        No
# 6   35  female  united_states           NaN            Yes       Yes
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 4          Never         100-500         Yes          Yes  ...  Don't know
# 5      Sometimes            6-25          No          Yes  ...  Don't know
# 6      Sometimes             1-5         Yes          Yes  ...          No
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 743 entries, 0 to 1258
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        743 non-null    int64
#  1   gender                     743 non-null    object
#  2   country                    743 non-null    object
#  3   self_employed              732 non-null    object
#  4   family_history             743 non-null    object
#  5   treatment                  743 non-null    object
#  6   work_interfere             602 non-null    object
#  7   no_employees               743 non-null    category
#  8   remote_work                743 non-null    object
#  9   tech_company               743 non-null    object
#  10  benefits                   743 non-null    object
#  11  care_options               743 non-null    object
#  12  wellness_program           743 non-null    object
# ...

# %%
df_2['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    289
# Never        122
# Rarely       111
# Often         80
# Name: count, dtype: int64

# %%
df_2['work_interfere'] = df_2['work_interfere'].fillna('unknown')
df_2['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    289
# unknown      141
# Never        122
# Rarely       111
# Often         80
# Name: count, dtype: int64
